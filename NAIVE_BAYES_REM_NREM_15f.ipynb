# %% [markdown]
# # NAIVE BAYES

# %%
# On importe les librairies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB,MultinomialNB,CategoricalNB

# %%
# On importe le dataset
f="/content/REM_NREM_15f.csv"
dataset = pd.read_csv(f)
dataset.head()
# Out:
#   Sleep_Stage  PeakF_Beta_F4  ...  PeakF_Delta_F4  Spectral Edge_Alpha_C4
# 0        NREM       14.36098  ...         0.74927                17.73268
# 1        NREM       16.60878  ...         0.62439                18.98146
# 2        NREM       14.98537  ...         0.37463                16.60878
# 3        NREM       11.36390  ...         0.99902                16.10927
# 4        NREM       15.98439  ...         2.87220                15.11024
#
# [5 rows x 16 columns]

# %%
# On sépare notre dataframe en deux les inputs et les targets ( survived )
X = dataset.drop('Sleep_Stage',axis='columns')
Y = dataset.Sleep_Stage

# %%
# Identifier les colonnes ou il manque des données
X.columns[X.isna().any()]
# Out:
# Index([], dtype='object')

# %%
X.describe()
# Out:
#        PeakF_Beta_F4  PeakF_Beta_C4  ...  PeakF_Delta_F4  Spectral Edge_Alpha_C4
# count    89096.00000   89096.000000  ...    89096.000000            89096.000000
# mean        20.65046      21.629436  ...        1.233448               14.857811
# std         19.37498      19.543395  ...        3.660213                5.263334
# min          3.87122       3.871220  ...        0.124880                0.124880
# 25%         10.73951      11.239020  ...        0.499510               13.237070
# 50%         12.61268      13.611710  ...        0.749270               14.236100
# 75%         17.85756      18.357070  ...        0.999020               15.360000
# max        127.87512     127.875120  ...       31.968780               50.076100
#
# [8 rows x 15 columns]

# %%
X.fillna(X.mean(), inplace=True)
X.describe()
# Out:
#        PeakF_Beta_F4  PeakF_Beta_C4  ...  PeakF_Delta_F4  Spectral Edge_Alpha_C4
# count    89096.00000   89096.000000  ...    89096.000000            89096.000000
# mean        20.65046      21.629436  ...        1.233448               14.857811
# std         19.37498      19.543395  ...        3.660213                5.263334
# min          3.87122       3.871220  ...        0.124880                0.124880
# 25%         10.73951      11.239020  ...        0.499510               13.237070
# 50%         12.61268      13.611710  ...        0.749270               14.236100
# 75%         17.85756      18.357070  ...        0.999020               15.360000
# max        127.87512     127.875120  ...       31.968780               50.076100
#
# [8 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %%
model = CategoricalNB()

# %%
model.fit(X_train,y_train)
# Out:
# CategoricalNB()

# %%
print(f)
print(model.score(X_train,y_train))
# Out:
# /content/REM_NREM_15f.csv
# 0.7291654975026657
