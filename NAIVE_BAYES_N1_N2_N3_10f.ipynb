# %% [markdown]
# # NAIVE BAYES

# %%
# On importe les librairies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB,MultinomialNB,CategoricalNB

# %%
# On importe le dataset
f="/content/N1_N2_N3_10f.csv"
dataset = pd.read_csv(f)
dataset.head()
# Out:
#   Sleep_Stage  MedianF_Beta_F4  ...  MedianF_Beta_O2  Spectral Edge_Alpha_F4
# 0          N1         17.73268  ...         18.23220                17.48293
# 1          N1         16.85854  ...         18.10732                17.10829
# 2          N1         17.35805  ...         17.23317                16.98341
# 3          N2         15.48488  ...         17.73268                15.85951
# 4          N2         15.11024  ...         15.98439                15.48488
#
# [5 rows x 11 columns]

# %%
# On sépare notre dataframe en deux les inputs et les targets ( survived )
X = dataset.drop('Sleep_Stage',axis='columns')
Y = dataset.Sleep_Stage

# %%
# Identifier les colonnes ou il manque des données
X.columns[X.isna().any()]
# Out:
# Index([], dtype='object')

# %%
X.describe()
# Out:
#        MedianF_Beta_F4  ...  Spectral Edge_Alpha_F4
# count     72631.000000  ...            72631.000000
# mean         16.434196  ...               14.137720
# std          14.792444  ...                4.217983
# min           6.243900  ...                0.124880
# 25%          12.113170  ...               12.737560
# 50%          13.486830  ...               13.736590
# 75%          15.484880  ...               14.985370
# max         127.875120  ...               50.076100
#
# [8 rows x 10 columns]

# %%
X.fillna(X.mean(), inplace=True)
X.describe()
# Out:
#        MedianF_Beta_F4  ...  Spectral Edge_Alpha_F4
# count     72631.000000  ...            72631.000000
# mean         16.434196  ...               14.137720
# std          14.792444  ...                4.217983
# min           6.243900  ...                0.124880
# 25%          12.113170  ...               12.737560
# 50%          13.486830  ...               13.736590
# 75%          15.484880  ...               14.985370
# max         127.875120  ...               50.076100
#
# [8 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %%
model = CategoricalNB()

# %%
model.fit(X_train,y_train)
# Out:
# CategoricalNB()

# %%
print(f)
print(model.score(X_train,y_train))
# Out:
# /content/N1_N2_N3_10f.csv
# 0.5591697645600991
