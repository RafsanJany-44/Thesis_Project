# %% [markdown]
# # NAIVE BAYES

# %%
# On importe les librairies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB,MultinomialNB,CategoricalNB

# %%
# On importe le dataset
f="/content/N1_N2_N3.csv"
dataset = pd.read_csv(f)
dataset.head()
# Out:
#   Sleep_Stage  MeanP_Alpha_F4  ...  Spectral Edge_Gamma_O2  PeakF_Gamma_O2
# 0          N1         0.00034  ...                49.95122        49.95122
# 1          N1         0.00035  ...                49.95122        49.95122
# 2          N1         0.00035  ...                49.95122        49.95122
# 3          N2         0.00050  ...                49.95122        49.95122
# 4          N2         0.00072  ...                49.95122        49.95122
#
# [5 rows x 76 columns]

# %%
# On sépare notre dataframe en deux les inputs et les targets ( survived )
X = dataset.drop('Sleep_Stage',axis='columns')
Y = dataset.Sleep_Stage

# %%
# Identifier les colonnes ou il manque des données
X.columns[X.isna().any()]
# Out:
# Index([], dtype='object')

# %%
X.describe()
# Out:
#        MeanP_Alpha_F4  MedianF_Alpha_F4  ...  Spectral Edge_Gamma_O2  PeakF_Gamma_O2
# count    7.263100e+04      72631.000000  ...            72631.000000    72631.000000
# mean     9.605778e-04          8.986572  ...               50.282262       43.072594
# std      6.190110e-03          1.897858  ...               10.042824       15.913365
# min      4.590000e-52          0.124880  ...               34.091710        5.369760
# 25%      4.100000e-04          8.366830  ...               48.202930       32.967800
# 50%      6.000000e-04          8.991220  ...               49.951220       49.951220
# 75%      9.300000e-04          9.740490  ...               50.076100       49.951220
# max      8.074400e-01         49.826340  ...              127.875120      127.875120
#
# [8 rows x 75 columns]

# %%
X.fillna(X.mean(), inplace=True)
X.describe()
# Out:
#        MeanP_Alpha_F4  MedianF_Alpha_F4  ...  Spectral Edge_Gamma_O2  PeakF_Gamma_O2
# count    7.263100e+04      72631.000000  ...            72631.000000    72631.000000
# mean     9.605778e-04          8.986572  ...               50.282262       43.072594
# std      6.190110e-03          1.897858  ...               10.042824       15.913365
# min      4.590000e-52          0.124880  ...               34.091710        5.369760
# 25%      4.100000e-04          8.366830  ...               48.202930       32.967800
# 50%      6.000000e-04          8.991220  ...               49.951220       49.951220
# 75%      9.300000e-04          9.740490  ...               50.076100       49.951220
# max      8.074400e-01         49.826340  ...              127.875120      127.875120
#
# [8 rows x 75 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %%
model = CategoricalNB()

# %%
model.fit(X_train,y_train)
# Out:
# CategoricalNB()

# %%
print(f)
print(model.score(X_train,y_train))
# Out:
# /content/N1_N2_N3.csv
# 0.6801769241360319
