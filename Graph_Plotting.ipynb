# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/Thesis_Project/blob/main/Graph_Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def graph(X,Y,horizontal,virtical,col="blue",type="bar"):
  import matplotlib.pyplot as plt
  fig, axs = plt.subplots(figsize=(horizontal, virtical), sharey=True)
  if type=="bar":
    axs.bar(X,Y,color=col)
  elif type=="scat":
    axs.scatter(X, Y,color=col)
  else:
    axs.plot(X, Y,color=col)

# %%
x=["Spectral Edge_Beta_F4","MedianF_Beta_F4","Spectral Edge_Beta_C4","Spectral Edge_Alpha_F4","PeakF_Beta_O2","MeanF_Alpha_F4",
   "Spectral Edge_Alpha_C4","MeanF_Beta_F4","MedianF_Beta_C4","MeanF_Alpha_C4"]
y=[11373.488527,9190.314853,8672.075254,8325.573715,7897.908333,6863.30969,5610.763284,5432.923221,4356.787096,4317.518029]
graph(x,y,30,10,"green")

# %%
x=["Spectral Edge_Beta_F4","MedianF_Beta_F4","Spectral Edge_Beta_C4","Spectral Edge_Alpha_F4","PeakF_Beta_O2","MeanF_Alpha_F4",
   "Spectral Edge_Alpha_C4","MeanF_Beta_F4","MedianF_Beta_C4","MeanF_Alpha_C4","PeakF_Theta_C4","MeanF_Beta_C4","PeakF_Theta_O2","MedianF_Theta_C4","MedianF_Theta_O2"]
y=[11373.488527,9190.314853,8672.075254,8325.573715,7897.908333,6863.30969,5610.763284,5432.923221,4356.787096,4317.518029,4037.671078,4023.870095,3924.855844,3748.523197,3734.659315]
graph(x,y,35,10)

# %%
x=["Spectral Edge_Beta_F4","MedianF_Beta_F4","Spectral Edge_Beta_C4","Spectral Edge_Alpha_F4","PeakF_Beta_O2","MeanF_Alpha_F4",
   "Spectral Edge_Alpha_C4","MeanF_Beta_F4","MedianF_Beta_C4","MeanF_Alpha_C4","PeakF_Theta_C4","MeanF_Beta_C4","PeakF_Theta_O2","MedianF_Theta_C4","MedianF_Theta_O2",'PeakF_Theta_F4','PeakF_Beta_C4','MeanF_Delta_C4','Spectral Edge_Alpha_O2','Spectral Edge_Gamma_F4']
y=[11373.488527,9190.314853,8672.075254,8325.573715,7897.908333,6863.30969,5610.763284,5432.923221,4356.787096,4317.518029,4037.671078,4023.870095,3924.855844,3748.523197,3734.659315,3063.144365,2739.971141,2628.359081,2596.380657,2482.252614]
graph(x,y,40,10)
